# %%
import pandas as pd
import numpy as np

from local.constants import WORKSPACE_ROOT
from local.figures.template import BaseFigure, ApplyTemplate, go
from local.figures.colors import COLORS, Color, Palettes

# %%
df = pd.read_csv(WORKSPACE_ROOT/"data/proteomics/epi300.protein.tsv", sep="\t")
print(df.shape)
df.head(2)
# Out:
# (2467, 60)
#    Protein Protein ID Entry Name Gene  Protein Length Organism  \
# 0    C1_10      C1_10      C1_10  NaN              69      NaN
# 1  C1_1001    C1_1001    C1_1001  NaN             302      NaN
#
#   Protein Existence Description  Protein Probability  Top Peptide Probability  \
# 0               NaN       C1_10                  1.0                    0.999
# 1               NaN     C1_1001                  1.0                    0.999
#
#    ...  76_Pic1011_4_F4_7G_100ng MaxLFQ Intensity  \
# 0  ...                               8.080826e+07
# 1  ...                               1.331771e+09
#
#    77_Pic1011_5_F5_8G_100ng MaxLFQ Intensity  \
# 0                               1.685832e+08
# 1                               1.086445e+09
#
#    78_Pic1011_6_F6_9G_100ng MaxLFQ Intensity  \
# 0                               1.154666e+08
# 1                               1.342404e+09
#
#    79_Pic1011_7_F7_10G_EP1300FOS_AA_2_100ng MaxLFQ Intensity  \
# 0                                       1.762026e+08
# 1                                       1.503298e+09
#
#    80_Pic1011_8_F8_11G_EP1300FOS_AA_2_100ng MaxLFQ Intensity  \
# 0                                       1.358641e+08
# 1                                       1.393202e+09
#
#    81_Pic1011_9_F9_12G_EP1300FOS_100ng MaxLFQ Intensity  \
# 0                                       1.321821e+08
# 1                                       1.383123e+09
#
#    82_Pic1011_1_D1_1GL_EP1300_PCC1_3_100ng MaxLFQ Intensity  \
# 0                                       7.503919e+07
# 1                                       2.536239e+09
#
#    83_Pic1011_2_D2_2GL_EP1300_PCC1_1_100ng MaxLFQ Intensity  \
# 0                                       9.081326e+07
# 1                                       2.525745e+09
#
#    84_Pic1011_3_D3_3GL_EP1300_PCC1_2_100ng MaxLFQ Intensity  \
# 0                                       9.223270e+07
# 1                                       2.103290e+09
#
#    Indistinguishable Proteins
# 0                         NaN
# 1                         NaN
#
# [2 rows x 60 columns]

# %%
cols = [c for c in df.columns if ("MaxLFQ" in c and "Intensity" in c)]
cols
# Out:
# ['76_Pic1011_4_F4_7G_100ng MaxLFQ Intensity',
#  '77_Pic1011_5_F5_8G_100ng MaxLFQ Intensity',
#  '78_Pic1011_6_F6_9G_100ng MaxLFQ Intensity',
#  '79_Pic1011_7_F7_10G_EP1300FOS_AA_2_100ng MaxLFQ Intensity',
#  '80_Pic1011_8_F8_11G_EP1300FOS_AA_2_100ng MaxLFQ Intensity',
#  '81_Pic1011_9_F9_12G_EP1300FOS_100ng MaxLFQ Intensity',
#  '82_Pic1011_1_D1_1GL_EP1300_PCC1_3_100ng MaxLFQ Intensity',
#  '83_Pic1011_2_D2_2GL_EP1300_PCC1_1_100ng MaxLFQ Intensity',
#  '84_Pic1011_3_D3_3GL_EP1300_PCC1_2_100ng MaxLFQ Intensity']

# %%
# https://docs.google.com/spreadsheets/d/1pc1L5qF5SErQMXlbOnYmGvAAvPalSgh2/edit?gid=2054370611#gid=2054370611
original_names = """
LB CM_EPFOS_C_water_1
LB CM_EPFOS_C_water_2
LB CM_EPFOS_C_water_3
LB CM_EPFOS_C_iAAl_1
LB CM_EPFOS_C_iAAl_2
LB CM_EPFOS_C_iAAl_3
LB CM_EPPCC1_C_1
LB CM_EPPCC1_C_2
LB CM_EPPCC1_C_3
""".split("\n")[1:-1]
name_map = {c: n for c, n in zip(cols, original_names)}
name_map
# Out:
# {'76_Pic1011_4_F4_7G_100ng MaxLFQ Intensity': 'LB CM_EPFOS_C_water_1',
#  '77_Pic1011_5_F5_8G_100ng MaxLFQ Intensity': 'LB CM_EPFOS_C_water_2',
#  '78_Pic1011_6_F6_9G_100ng MaxLFQ Intensity': 'LB CM_EPFOS_C_water_3',
#  '79_Pic1011_7_F7_10G_EP1300FOS_AA_2_100ng MaxLFQ Intensity': 'LB CM_EPFOS_C_iAAl_1',
#  '80_Pic1011_8_F8_11G_EP1300FOS_AA_2_100ng MaxLFQ Intensity': 'LB CM_EPFOS_C_iAAl_2',
#  '81_Pic1011_9_F9_12G_EP1300FOS_100ng MaxLFQ Intensity': 'LB CM_EPFOS_C_iAAl_3',
#  '82_Pic1011_1_D1_1GL_EP1300_PCC1_3_100ng MaxLFQ Intensity': 'LB CM_EPPCC1_C_1',
#  '83_Pic1011_2_D2_2GL_EP1300_PCC1_1_100ng MaxLFQ Intensity': 'LB CM_EPPCC1_C_2',
#  '84_Pic1011_3_D3_3GL_EP1300_PCC1_2_100ng MaxLFQ Intensity': 'LB CM_EPPCC1_C_3'}

# %%
df_exp = df[~df["Protein"].str.contains("sp")]
print(df_exp.shape)
# Out:
# (2459, 60)

# %%
mat = df_exp[cols].to_numpy()
mat.shape
# Out:
# (2459, 9)

# %%
proteins = df_exp["Protein"].values
annotation_map = {p: dict() for p in proteins}
len(proteins)
# Out:
# 2459

# %%
proteins
# Out:
# array(['C1_10', 'C1_1001', 'C1_1002', ..., 'C1_99', 'C1_993', 'C1_994'],
#       dtype=object)

# %%
df_swissprot = pd.read_csv(WORKSPACE_ROOT/"data/annotations/epi300/epi300.swissprot.csv")
print(df_swissprot.shape)
for _, r in df_swissprot.iterrows():
    k = f"{r.contig}_{r.orf}"
    desc = r.description

    meta = dict(t.split("=") for t in desc.split(" ") if "=" in t)
    gene = meta.get("GN", None)
    if k not in annotation_map: continue
    annotation_map[k]["swissprot"] = [gene, desc]

df_swissprot.head(2)
# Out:
# (3796, 7)
#   contig  orf                ref_id  \
# 0     C1    1  sp|P16917|RHSB_ECOLI
# 1     C1   10  sp|P0C266|YIBT_SHIFL
#
#                                          description      bsr        evalue  \
# 0  Protein RhsB OS=Escherichia coli (strain K12) ...  0.88135  0.000000e+00
# 1  Uncharacterized protein YibT OS=Shigella flexn...  1.00000  1.343700e-45
#
#    percent_identity
# 0              98.0
# 1             100.0

# %%
mat_control = mat[:, [0, 1, 2]]
mat_atf1 = mat[:, [3, 4, 5]]
mat_blank = mat[:, [6, 7, 8]]

# %%
from scipy.stats import ttest_ind

# %%
def ttest(matA: np.ndarray, matB: np.ndarray, labels: list[str]):
    combined = np.hstack([matA, matB])
    missing_vals = (combined == 0).sum(axis=1) > 0
    matA_nonz = matA[~missing_vals]
    matB_nonz = matB[~missing_vals]
    labels = np.array(labels)
    removed = labels[missing_vals]
    kept = labels[~missing_vals]

    res = ttest_ind(matA_nonz, matB_nonz, axis=1, equal_var=False)
    pvals = res.pvalue

    valA = matA_nonz.mean(axis=1)
    valB = matB_nonz.mean(axis=1)
    fold_change = valB/valA

    return fold_change, pvals, kept, removed

blank_v_control = ttest(mat_blank, mat_control, proteins)
blank_v_atf1 = ttest(mat_blank, mat_atf1, proteins)

# %%
fig = BaseFigure(shape=(2, 1))

def _add(results, col):
    fold_change, pvals, kept, removed = results
    fc_good = np.abs(np.log2(fold_change))>1
    pval_good = pvals < 0.001
    selected = fc_good & pval_good
    fig.add_trace(go.Scatter(
        x=np.log2(fold_change[~selected]),
        y=-np.log10(pvals[~selected]),
        mode="markers",
        marker=dict(
            color=Color.Hex("AAAAAA").color_value,
            size=4,
        ),
        text=[annotation_map.get(k, {}).get("swissprot", [k, None])[0] for k in kept],
        showlegend=False,
    ), row=1, col=col)

    fig.add_trace(go.Scatter(
        x=np.log2(fold_change[selected]),
        y=-np.log10(pvals[selected]),
        mode="markers",
        marker=dict(
            color=COLORS.RED,
            # color=Palettes.PLOTLY[1].color_value,
            size=4,
        ),
        text=[annotation_map.get(k, {}).get("swissprot", [None, k]) for k in kept],
        showlegend=False,
    ), row=1, col=col)

    pv, fc = 3, 1
    fig.add_trace(go.Scatter(
        x=[-fc, -fc, None, fc, fc, None, -100, 100, None],
        y=[-100, 100, None, -100, 100, None, pv, pv, None],
        mode="lines",
        line=dict(
            color=Color.Hex("212121").color_value,
            dash="dash",
            width=0.5,
        ),
        showlegend=False,
    ), row=1, col=col)

_add(blank_v_control, 1)
_add(blank_v_atf1, 2)

xlabels = [f"{2**v}" for v in range(-6, 7)]
fig = ApplyTemplate(
    fig,
    default_yaxis=dict(range=[-0.1, 5.1]),
    default_xaxis=dict(range=[-5.5, 5.5]),
    axis={
        "2 1 y": dict(showticklabels=False, showline=False, ticks=None),
        "1 1 y": dict(title="-log10 p-value"),
        "1 1 x": dict(title="control vs blank"),
        "2 1 x": dict(title="control vs atf1"),
    },
    layout=dict(
        width=1200, height=600,
    ),
)

fig.write_html("./cache/volcano.html")
fig.show()
# Out:
# <div>                            <div id="25ac8ced-5185-4034-aab8-1135c096174a" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25ac8ced-5185-4034-aab8-1135c096174a")) {                    Plotly.newPlot(                        "25ac8ced-5185-4034-aab8-1135c096174a",                        [{"marker":{"color":"rgba(170.0000,170.0000,170.0000,1.0000)","size":4},"mode":"markers","showlegend":false,"text":["yibT","yagE","yagF","yagH","yagU","rclA","ykgE","ykgF","ykgG","betB","dgoR","yaiL","frmA","C1_1059","yidA","hemB","yaiW","ddlA","psiF","proC","C1_1088","gyrB","C1_1092","C1_1094","mak","sbcC","yibL","proY","malZ","C1_1105","C1_1106","yajC","secD","secF","dnaN","yajI","C1_1113","ribD","C1_1115","C1_1116","thiL","yajO","dnaA","dxs","ispA","thiI","yajL","panE","C1_1126","C1_113","cyoB","cyoA","yajG","bolA","C1_1136","C1_1137","C1_1138","lon","C1_114","hupB","ppiD","queC","yidC","tesB","ybaY","maa","mnmE","mexB","acrA","mscK","C1_1168","C1_117","C1_1170","htpG","C1_1173","hemH","gsk","ybaL","ushA","ybaK","copA","glsA1","qmcA","fetA","fetB","tesA","allR","chrR","purE","ppiB","cysS","ybcJ","folD","C1_1251","borD","ompT","ybcH","nfrA","cusR","pheP","ybdG","nfsB","ybdK","fepA","fepB","dsbG","ahpC","ahpF","uspG","ybdR","rnk","rna","citF","citE","C1_1320","dpiA","cspE","phoU","C1_1331","C1_1333","C1_1334","dacA","rlpA","mrdB","mrdA","C1_1339","pstB","C1_1342","holA","C1_1344","leuS","ybeL","rihA","gltL","gltJ","gltI","pstS","glmS","glmU","lldD","C1_140","C1_141","C1_142","C1_143","C1_144","C1_145","C1_146","lnt","corC","ybeZ","C1_1472","ubiF","asnB","nagD","nagC","nagA","C1_1478","nagE","glnS","fur","fldA","ybfF","seqA","pgm","kdpE","kdpD","trmL","C1_150","ybfA","ybgA","ybgI","pxpC","nei","asnC","gltA","sdhD","sdhA","sdhB","sucA","sucB","C1_1529","asnA","sucD","cydA","cydB","tolQ","tolR","C1_1542","pal","cpoB","aroG","ravA","C1_1550","galM","galT","galE","modE","modA","ybhA","pgl","rbsD","ybhC","ybhB","C1_1577","ybhK","rbsA","moaB","C1_1581","moaE","ybhP","ybhR","ybhF","ybhG","cecR","rhlE","ybiB","hcxB","cysE","rbsB","rlmF","glnQ","glnH","rbsK","C1_1610","ompX","mntR","ybiS","ybiT","ybiV","moeB","moeA","gsiB","C1_1633","gstB","dacC","ybjI","grxA","nfsA","artJ","artI","artP","ybjP","C1_1664","amiD","ybjS","ybjT","ltaE","poxB","yieP","hcr","macA","cspD","clpA","C1_1681","cydC","trxB","lrp","C1_1688","rarA","C1_169","C1_1690","ynfE","dmsB","dmsC","ycaC","pflA","C1_17","yifE","pflB","focA","ycaO","serC","C1_1705","C1_1707","rpsA","C1_1709","msbA","lpxK","kdsB","ycbJ","C1_1719","mukE","mukB","ycbB","gloC","aspC","ompF","C1_1727","pepN","C1_1742","ycbX","rlmL","uup","pqiB","pqiC","C1_1750","C1_1751","ycbZ","C1_1753","ompA","yccS","yccF","helD","ilvE","yccU","rlmI","yccX","tusE","hyaA","hyaB","ilvD","appC","appB","appA","ilvA","C1_1788","cbpA","agp","C1_18","ilvC","yccJ","C1_1801","ppiC","putA","rep","ghrA","ycdX","ycdY","gppA","ymdB","mdoG","opgH","msyB","C1_185","solA","pyrC","trxA","yceB","grxB","rimJ","yceH","yceM","rho","rne","rluC","yceF","yceD","C1_1885","plsX","fabH","fabD","fabG","wecA","C1_1890","fabF","mltG","C1_1894","ycfH","ptsG","hinT","grxC","wzzE","lpoB","nagZ","C1_1904","ndh","wecB","mfd","lolC","lolD","lolE","cobB","potD","wecC","potA","pepT","roxA","phoQ","phoP","purB","C1_1928","rffG","C1_1930","rluE","icd","minD","minC","pliG","C1_1950","ycgM","hlyE","ycgB","wecE","C1_1960","nhaP2","ldcA","treA","dhaM","dhaL","dhaK","ychF","C1_1977","dauA","prs","C1_1982","C1_1984","C1_1988","chaB","ychN","narL","yibN","wecG","narZ","narH","narI","purU","rssA","galU","hns","tdk","adhE","oppA","oppF","kch","hemY","40","hemX","hemD","C1_2062","hemC","lacI","cya","tnpX","yciA","C1_209","yciC","ompW","yciE","yciF","trpA","trpB","trpC","gpmI","yifL","yciO","rluB","btuR","yciK","sohB","topA","cysB","C1_211"," ...
